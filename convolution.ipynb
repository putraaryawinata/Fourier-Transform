# %%
import tensorflow as tf
import numpy as np
import PIL

from sklearn.model_selection import train_test_split
from PIL import Image
from numpy import asarray

# %%
path = 'F:/belajar/dataset-MONDI/class_ds/train/'
labels = ['A_fix', 'A_rotate_left', 'A_rotate_right',
         'B_fix', 'B_rotate_left', 'B_rotate_right',
         'C_fix', 'C_rotate_left', 'C_rotate_right',
         'D_fix', 'D_rotate_left', 'D_rotate_right',
         'E_fix', 'E_rotate_left', 'E_rotate_right']

images = []
for i in range(len(labels)):
    images_i = os.listdir(f"{path}{labels[i]}")
    images.append(images_i)

# %%
x = []
y = []
for i, label in enumerate(labels):
    for j, image in enumerate(images[i]):
        im = Image.open(f"{path}{label}/{image}")
        size = (224, 224) # input size
        im = im.resize(size)
        arr = asarray(im) / 255.
        x.append(arr)
        y.append(i)
        print(f"{label} ({j+1}/{len(images[i])})")
# Out:
# A_fix (1/2673)
# A_fix (2/2673)
# A_fix (3/2673)
# A_fix (4/2673)
# A_fix (5/2673)
# A_fix (6/2673)
# A_fix (7/2673)
# A_fix (8/2673)
# A_fix (9/2673)
# A_fix (10/2673)
# A_fix (11/2673)
# A_fix (12/2673)
# A_fix (13/2673)
# A_fix (14/2673)
# A_fix (15/2673)
# A_fix (16/2673)
# A_fix (17/2673)
# A_fix (18/2673)
# A_fix (19/2673)
# A_fix (20/2673)
# A_fix (21/2673)
# A_fix (22/2673)
# A_fix (23/2673)
# A_fix (24/2673)
# A_fix (25/2673)
# A_fix (26/2673)
# A_fix (27/2673)
# A_fix (28/2673)
# A_fix (29/2673)
# A_fix (30/2673)
# A_fix (31/2673)
# A_fix (32/2673)
# A_fix (33/2673)
# A_fix (34/2673)
# A_fix (35/2673)
# A_fix (36/2673)
# A_fix (37/2673)
# A_fix (38/2673)
# A_fix (39/2673)
# A_fix (40/2673)
# A_fix (41/2673)
# A_fix (42/2673)
# A_fix (43/2673)
# A_fix (44/2673)
# A_fix (45/2673)
# A_fix (46/2673)
# A_fix (47/2673)
# A_fix (48/2673)
# A_fix (49/2673)
# A_fix (50/2673)
# A_fix (51/2673)
# A_fix (52/2673)
# A_fix (53/2673)
# A_fix (54/2673)
# A_fix (55/2673)
# A_fix (56/2673)
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.05, random_state=42)

# %%
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
np.save('dataset-numpy/x_train.npy', x_train)
np.save('dataset-numpy/x_test.npy', x_test)
np.save('dataset-numpy/y_train.npy', y_train)
np.save('dataset-numpy/y_test.npy', y_test)

# %%
def normalize(arr):
    norm_arr = arr / 255.
    return norm_arr

# %%
norm_arr = normalize(arr)
print(norm_arr.shape)
